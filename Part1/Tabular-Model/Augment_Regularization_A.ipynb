# %% [markdown]
# <a href="https://colab.research.google.com/github/Bryan-Az/Adv-Keras-NNs/blob/main/Part1/Tabular-Model/Augment_Regularization_A.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <a href="https://colab.research.google.com/github/Bryan-Az/TF-PyTorch-Jax-NN/blob/main/Tensorflow-NN/EinsumVMatrix.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # An AB Test of Augmented Data and Regularizations

# %% [markdown]
# # Imports

# %%
# time-series data augmentation for numeric data
# !pip install tsaug
import tsaug
import numpy as np
from tsaug.visualization import plot

# model creation
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
# Out:
# Requirement already satisfied: tsaug in /usr/local/lib/python3.10/dist-packages (0.2.1)
# Requirement already satisfied: numpy>=1.14 in /usr/local/lib/python3.10/dist-packages (from tsaug) (1.25.2)
# Requirement already satisfied: scipy>=1.1 in /usr/local/lib/python3.10/dist-packages (from tsaug) (1.11.4)

# %%
# for the keras tensorflow model
from tensorflow.keras import layers
from tensorflow.keras import Sequential

# %% [markdown]
# # Creating Augmented Data using Environmental Data Distributions

# %% [markdown]
# # Loading and Processing Numerical Features
# This will help when processing with the regression model. This data was previously processed in my 'Keras-HF-FastAi' repository when preparing it to be used with the HuggingFace pre-trained "Tabular Question Answering" M.L model. During an earlier processing step when preparing the data for training with FastAi API model-training data loader methods and Sci-kit Learn's "AdaBoostRegressor" model, it was noticed that the data performed better in regression when the original features like working_capacity, fish_production, crop_production_capacity, etc were split into its tuple components, versus when the tuple components were merged into a single feature. This may be due to each component (feature_1, feature_2, etc.) representing a distinct latent variable. For further information for how the data was processed, refert to my 'Keras-HF-FastAi' repository.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials

# importing the file into the environment using google drive

auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)

fname_link_gdrive = {'corp_safeguard_split.csv':'https://drive.google.com/file/d/1mj0mWTZkmrmfD3ItSYrCrf6wGOBkEtau/view?usp=drive_link'}
# Out:
# WARNING:root:pydrive is deprecated and no longer maintained. We recommend that you migrate your projects to pydrive2, the maintained fork of pydrive

# %%
csv_name = list(fname_link_gdrive.keys())[0]
id = fname_link_gdrive[csv_name].split("/")[-2]
downloaded = drive.CreateFile({'id':id})
downloaded.GetContentFile(csv_name)

# %%
environmental_data = pd.read_csv('corp_safeguard_split.csv')

# %%
environmental_data.head()
# Out:
#    working_capacity_0  working_capacity_1  working_capacity_2  \
# 0                  69                  39               394.0
# 1                   1                  75                76.0
# 2                   1                  83                85.0
# 3                   1                  93                12.0
# 4                  91                  62               390.0
#
#    working_capacity_3  fish_production_capacity_0  fish_production_capacity_1  \
# 0          445.799955                           1                       763.0
# 1          865.000000                           4                       191.0
# 2          456.000000                           4                       273.0
# 3          582.000000                           4                       522.0
# 4          445.799955                           3                       149.0
#
#    crop_production_capacity_0  crop_production_capacity_1  \
# 0                          90                       516.0
# 1                           2                        34.0
# 2                           2                        43.0
# 3                           2                        56.0
# 4                           1                        26.0
#
#    crop_production_capacity_2  meat_production_capacity_0  ...  \
# 0                  437.036571                          21  ...
# 1                   20.000000                          54  ...
# 2                  627.000000                          56  ...
# 3                  694.000000                          60  ...
# 4                  821.000000                          28  ...
#
#    biodiversity_0  biodiversity_1  abiotic_resources_0  abiotic_resources_1  \
# 0             310       418.64977                  3.0                850.0
# 1             766       418.64977                  3.0                661.0
# 2             783       418.64977                  3.0                489.0
# 3             820       418.64977                  3.0                428.0
# 4             597       418.64977                  1.0                 94.0
#
#    water_production_capacity_(drinking_water_&_irrigation_water)_0  \
# 0                                                  2
# 1                                                 56
# 2                                                 33
# 3                                                  1
# 4                                                 47
#
#    water_production_capacity_(drinking_water_&_irrigation_water)_1  \
# 0                                               40.0
# 1                                               57.0
# 2                                               90.0
# 3                                                5.0
# 4                                               45.0
#
#    water_production_capacity_(drinking_water_&_irrigation_water)_2  Year  \
# 0                                                3.0                2018
# 1                                              645.0                2018
# 2                                               60.0                2018
# 3                                              662.0                2018
# 4                                              756.0                2018
#
#            Company Name  target
# 0    APPLUS SERVICES SA -0.2512
# 1    TELEPERFORMANCE SE -0.0428
# 2                SGS SA -0.0213
# 3    INTERTEK GROUP PLC -0.0339
# 4  THOMSON REUTERS CORP -0.0191
#
# [5 rows x 21 columns]

# %% [markdown]
# ## Feature Selection for Modelling and Augmentation of the Time Series Feature Distributions
# In the Numpy notebook, exploratory data analysis was used to find 2-3 features within the data that would be good choices to non linear regression. In this section, a similar method will be used to apply non-linear regression using Tensorflow low-level functionality that also allows for the creation of a regression model in an object-oriented fashion. For the generation of the synthetic distributions, we need to identify the distribution type and the distribution parameters within the base data, as each variable feature has different distribution characteristics.

# %% [markdown]
# ### Identifying the distributions & the distribution parameters

# %%
numerical_features = environmental_data.drop(['Company Name'], axis=1)

# %% [markdown]
# In this notebook, I will be using the same 3 features (+ the target) identified using the boxplot in the numpy notebook to generate the synthetic distributions. This time, I will be plotting the results in a 4D-plot. I am filtering the data to remove outliers and selecting the 5 most recent years.

# %%
numerical_features.shape
# Out:
# (13177, 20)

# %%
most_recent_year = numerical_features['Year'].max()

# Select rows that are within the 5 most recent years
recent_features = numerical_features[numerical_features['Year'] > most_recent_year - 5]

# %%
year_column = numerical_features['Year']

# %%
recent_features = recent_features.drop('Year', axis=1) # dropping year as it is not a environmental signal

# %%
means = recent_features.mean()
stds = recent_features.std()

# Calculate ymin and ymax for each column
ymins = means - 3 * stds
ymaxs = means + 3 * stds

# Filtering the DataFrame to only include values within ymin and ymax for each column
filtered_numerical_features = recent_features[(recent_features >= ymins) & (recent_features <= ymaxs)].dropna()

# %%
print(numerical_features.shape)
print(filtered_numerical_features.shape)
# Out:
# (13177, 20)
# (6557, 19)

# %%
filtered_numerical_features.describe()
# Out:
#        working_capacity_0  working_capacity_1  working_capacity_2  \
# count         6557.000000         6557.000000         6557.000000
# mean            20.038585           47.946317          166.746314
# std             25.243661           28.918262          249.319003
# min              1.000000            0.000000            0.000000
# 25%              3.000000           23.000000           32.000000
# 50%              8.000000           47.000000           65.000000
# 75%             27.000000           73.000000           97.000000
# max             97.000000          185.000000          999.000000
#
#        working_capacity_3  fish_production_capacity_0  \
# count         6557.000000                 6557.000000
# mean           443.951521                   55.387067
# std            266.964169                  129.647023
# min              0.000000                    1.000000
# 25%            240.000000                    3.000000
# 50%            445.799955                    9.000000
# 75%            614.000000                   31.000000
# max            999.000000                  706.000000
#
#        fish_production_capacity_1  crop_production_capacity_0  \
# count                 6557.000000                 6557.000000
# mean                   404.281205                   19.543389
# std                    298.084564                   24.676803
# min                      0.000000                    1.000000
# 25%                    103.000000                    3.000000
# 50%                    400.997112                    8.000000
# 75%                    649.000000                   26.000000
# max                    999.000000                  141.000000
#
#        crop_production_capacity_1  crop_production_capacity_2  \
# count                 6557.000000                 6557.000000
# mean                   140.833350                  436.210039
# std                    221.374304                  271.516195
# min                      0.000000                    0.000000
# 25%                     27.000000                  214.000000
# 50%                     57.000000                  437.036571
# 75%                     92.000000                  617.000000
# max                    957.000000                  999.000000
#
#        meat_production_capacity_0  meat_production_capacity_1  biodiversity_0  \
# count                 6557.000000                 6557.000000     6557.000000
# mean                    21.488181                  257.649295      138.462102
# std                     28.661700                  300.369591      226.135342
# min                      1.000000                    0.000000        1.000000
# 25%                      2.000000                   38.000000        2.000000
# 50%                      9.000000                   83.000000       14.000000
# 75%                     32.000000                  457.000000      197.000000
# max                    382.000000                  999.000000      887.000000
#
#        biodiversity_1  abiotic_resources_0  abiotic_resources_1  \
# count     6557.000000          6557.000000          6557.000000
# mean       420.556388            50.673241           353.629845
# std        239.393191           117.611291           295.907676
# min          0.000000             0.000000             0.000000
# 25%        276.000000             3.000000            73.000000
# 50%        418.649770            10.000000           357.948948
# 75%        505.000000            35.000000           576.000000
# max        999.000000           694.000000           999.000000
#
#        water_production_capacity_(drinking_water_&_irrigation_water)_0  \
# count                                        6557.000000
# mean                                           20.977429
# std                                            24.889863
# min                                             1.000000
# 25%                                             3.000000
# 50%                                            10.000000
# 75%                                            32.000000
# max                                            99.000000
#
#        water_production_capacity_(drinking_water_&_irrigation_water)_1  \
# count                                        6557.000000
# mean                                           99.035405
# std                                           156.221839
# min                                             0.000000
# 25%                                            26.000000
# 50%                                            53.000000
# 75%                                            84.000000
# max                                           808.000000
#
#        water_production_capacity_(drinking_water_&_irrigation_water)_2  \
# count                                        6557.000000
# mean                                          328.361269
# std                                           293.447537
# min                                             0.000000
# 25%                                            65.000000
# 50%                                           322.000000
# 75%                                           534.000000
# max                                           999.000000
#
#             target
# count  6557.000000
# mean     -1.143813
# std       5.008250
# min     -97.108400
# 25%      -0.511900
# 50%      -0.105000
# 75%      -0.028000
# max      44.022300

# %% [markdown]
# ## Creating a mask on the timeseries for plotting regions of interest before and after augmentation

# %%
filtered_numerical_features['Year'] = year_column

# %%
filtered_numerical_features.sort_values(by='Year', inplace=True)

# %%
#segmentation mask of it selects areas within the last 7 years
year_recent_mask = filtered_numerical_features['Year'] > 2017.0

# %%
# segmentation mask of biodiversity_0 for use with the tsaug visualization.plot function - it selects areas where the distribution is <300 (to the left of the tail) in numpy
biodiversity_0_mask = filtered_numerical_features['biodiversity_0'] < 300.0

# %%
plot(filtered_numerical_features.loc[:, 'biodiversity_0'].to_numpy(),  biodiversity_0_mask.to_numpy() & year_recent_mask.to_numpy())
# Out:
# (<Figure size 1600x200 with 1 Axes>, <Axes: >)

# %%
# helps visualize the spike that is seen on the feature distribution in time - - it selects the area to the left of the spike near 400
biodiversity_1_mask_1 = filtered_numerical_features['biodiversity_1'] < 400.0
biodiversity_1_mask = biodiversity_1_mask_1

# %%
plot(filtered_numerical_features.loc[:, 'biodiversity_1'].to_numpy(), biodiversity_1_mask.to_numpy() & year_recent_mask.to_numpy())
# Out:
# (<Figure size 1600x200 with 1 Axes>, <Axes: >)

# %%
#segmentation mask of working_capacity_3 - it selects the area to the left of the spike near 400
working_capacity_3_mask = filtered_numerical_features['working_capacity_3'] < 400.0

# %%
plot(filtered_numerical_features.loc[:, 'working_capacity_3'].to_numpy(), working_capacity_3_mask.to_numpy() & year_recent_mask.to_numpy())
# Out:
# (<Figure size 1600x200 with 1 Axes>, <Axes: >)

# %%
#segmentation mask of target - it selects areas in the range -0.511 to 0.64
target_mask = (filtered_numerical_features['target'] > -80) & (filtered_numerical_features['target'] < 40)

# %%
plot(filtered_numerical_features.loc[:, 'target'].to_numpy(), target_mask.to_numpy() & year_recent_mask.to_numpy())
# Out:
# (<Figure size 1600x200 with 1 Axes>, <Axes: >)

# %%
X = filtered_numerical_features.loc[:, ['biodiversity_0', 'biodiversity_1','working_capacity_3']].copy(deep=True)

# %%
y = filtered_numerical_features.loc[:, 'target'].copy(deep=True)

# %%
def plot_4d(x, y, z, c, title='4D Plot'):
    """ This function plots the 3 X variables
    as points, and uses color to visualize the target variable.
    """
    fig = plt.figure()
    ax = fig.add_subplot(111, projection='3d')

    # Assuming x, y, z, and c are numpy arrays or lists of the same length
    # x, y, and z are the coordinates, and c is the color dimension
    ax.scatter(x, y, z, c=c, cmap=plt.hot())

    # Add a colorbar to represent the fourth dimension
    fig.colorbar(ax.scatter(x, y, z, c=c, cmap=plt.hot()),ax=ax, label='Environmental Cost Intensity (%)')

    plt.title(title)
    plt.show()

# %%
plot_4d(X['biodiversity_0'], X['biodiversity_1'], X['working_capacity_3'], y, title='Biodiversity (0 & 1) & working capacity (3) features in 2018 colored by Target')

# %%
# Create a figure and a grid of subplots
fig, axs = plt.subplots(1, 3, figsize=(3 * 5, 4))

# Flatten the array of axes (subplots) for easy iteration
axs_flat = axs.flatten()

for i, column in enumerate(X.columns):
    # Plot the column data in its own subplot
    filtered_numerical_features[column].plot(kind='hist', bins=20, ax=axs_flat[i])
    axs_flat[i].set_title(column)

# %%
y.plot(kind='hist', bins=100)
# Out:
# <Axes: ylabel='Frequency'>

# %% [markdown]
# Thoughts on the underlying distributions based on the histograms:
# 1. The biodiversity_0 feature may be an inverse exponential distribution.
# 2. The biodiversity_1 feature may be an irregular gaussian as there is a spike near 400.
# 3. The working_capacity_3 feature may also be an irregular gaussian as there is a spike near 400.
# 4. The target (environmental cost intensity) feature may be an exponential distribution shifted to the left.

# %% [markdown]
# Further hypothesis testing may be done to uncover the underlying distributions generating the data, however, for the purposes of this assignment I will continue by generating the data based on these assumptions.

# %% [markdown]
# ### Generating the Augmented Data
# I'll be applying TSAug to hopefully create a dataset having augmented data based on an estimation of the underlying time series distribution of the three selected variables.
#
# We noticed that the visualization of the features in time looks much different than the visualization of the features without the time variable - this is a tricky distribution and hopefully TSAug can create augmented data that complements this data and is similar in distribution for testing and experimentation with our model.

# %%
from tsaug import TimeWarp, Crop, Quantize, Drift, Reverse

# %%
env_data_tsaug = (
    Crop(size=2000) # create a subset augmented set of size n
    + Quantize(n_levels=[10,20,30]) # random quantization level sets
    + Drift(max_drift=(0.01,0.02)) @ 0.8 # randomly drift the data up by 1-2%
    + Reverse() @ 0.5 # randomly reverse the pattern 50% of the time
)

# %%
biodiv0_aug, y_biodiv0_aug = env_data_tsaug.augment(filtered_numerical_features['biodiversity_0'].to_numpy(), biodiversity_0_mask.to_numpy() & year_recent_mask.to_numpy())
biodiv1_aug, y_biodiv1_aug = env_data_tsaug.augment(filtered_numerical_features['biodiversity_1'].to_numpy(), biodiversity_1_mask.to_numpy())
working_aug, y_working_aug = env_data_tsaug.augment(filtered_numerical_features['working_capacity_3'].to_numpy(), working_capacity_3_mask.to_numpy())
target_aug, y_target_aug = env_data_tsaug.augment(filtered_numerical_features['target'].to_numpy(), target_mask.to_numpy())

# %% [markdown]
# ## Augmenting the X Features

# %%
plot(biodiv0_aug, y_biodiv0_aug) # top plot shows the distribution post augmentation, bottom plot shows the mask to select areas to b
# Out:
# (<Figure size 1600x200 with 1 Axes>, <Axes: >)

# %%
plot(biodiv1_aug, y_biodiv1_aug)
# Out:
# (<Figure size 1600x200 with 1 Axes>, <Axes: >)

# %%
plot(working_aug, y_working_aug)
# Out:
# (<Figure size 1600x200 with 1 Axes>, <Axes: >)

# %% [markdown]
# ## Augmenting the Y Feature

# %%
plot(target_aug, y_target_aug) # as we can see, the target variable is not masked in the areas with the outliers
# Out:
# (<Figure size 1600x200 with 1 Axes>, <Axes: >)

# %%
# merge biodiv0_aug, biodiv1_aug, and working_aug into a new dataframe with these names for their respective columns
augmented_data = pd.DataFrame({'biodiversity_0': biodiv0_aug, 'biodiversity_1': biodiv1_aug, 'working_capacity_3': working_aug, 'target': target_aug})

# %% [markdown]
# The augmented data created with TSAug seems to match some of the key distribution estimators of the original data, such as the standard deviation, mean, and quantiles! This may provide a more fine-grained look at particular sections of the data such as the most recent information and areas of the distribution that are more signal-rich - such as biodiv1 (it has more red due to having a larger mask region).

# %%
filtered_numerical_features.loc[:, ['biodiversity_0', 'biodiversity_1','working_capacity_3', 'target']].describe()
# Out:
#        biodiversity_0  biodiversity_1  working_capacity_3       target
# count     6557.000000     6557.000000         6557.000000  6557.000000
# mean       138.462102      420.556388          443.951521    -1.143813
# std        226.135342      239.393191          266.964169     5.008250
# min          1.000000        0.000000            0.000000   -97.108400
# 25%          2.000000      276.000000          240.000000    -0.511900
# 50%         14.000000      418.649770          445.799955    -0.105000
# 75%        197.000000      505.000000          614.000000    -0.028000
# max        887.000000      999.000000          999.000000    44.022300

# %%
augmented_data.describe()
# Out:
#        biodiversity_0  biodiversity_1  working_capacity_3       target
# count     2000.000000     2000.000000         2000.000000  2000.000000
# mean       161.932200      446.752800          475.821103    -0.199487
# std        225.823378      235.141685          269.073740     4.574347
# min         23.100000       24.975000           10.854509   -75.850113
# 25%         23.100000      324.675000          280.236662    -0.347974
# 50%         23.100000      424.575000          451.622899     0.193973
# 75%        244.100000      524.475000          681.690909     0.715309
# max        862.900000      974.025000          994.205575    37.730914

# %%
# Create a figure and a grid of subplots
fig, axs = plt.subplots(1, 4, figsize=(4 * 4, 4))

# Flatten the array of axes (subplots) for easy iteration
axs_flat = axs.flatten()

for i, column in enumerate(augmented_data.columns):
    # Plot the column data in its own subplot
    augmented_data[column].plot(kind='hist', bins=30, ax=axs_flat[i])
    axs_flat[i].set_title(column)
plt.tight_layout()  # Adjust the layout to make sure there's no overlap
plt.show()

# %% [markdown]
# ## Scaling the Augmented Numerical Data

# %%
standard_scaler = StandardScaler()
X_scaled=standard_scaler.fit_transform(augmented_data.iloc[:, :-1])

# %%
y_scaled = standard_scaler.fit_transform(augmented_data.iloc[:,-1].to_numpy().reshape(-1, 1))

# %%
print(X_scaled.shape)
print(y_scaled.shape)
# Out:
# (2000, 3)
# (2000, 1)

# %%
X_scaled.dtype
# Out:
# dtype('float64')

# %% [markdown]
# ## Data Transformation

# %%
# using sklearn to split the data
X_train, X_test, y_train, y_test = train_test_split(X_scaled,
                                                    y_scaled,
                                                    test_size=0.2,
                                                    random_state=88)

# %%
# creating the test/train split
tf_train_dataset = tf.data.Dataset.from_tensor_slices((X_train, y_train)).shuffle(buffer_size=1024).batch(8)
tf_test_dataset = tf.data.Dataset.from_tensor_slices((X_train, y_train)).shuffle(buffer_size=1024).batch(8)

# %% [markdown]
# # A Tensorflow Model A/B Test of Regularizations

# %% [markdown]
# This notebook uses the low-Level Sequential API, whereas notebook B uses the high-level Keras API.

# %%
from tensorflow.keras.regularizers import l1, l2

# %% [markdown]
# # Batch Norm
# This model uses the keras api Einsum method in the forward pass to update the nodes. 3 variable features will be used in the non linear equation for this 3-layer deep model. Synthetically generated data with 3 variables will be processed with the non-linear equation and plotted using a 4d plot.

# %%
# Instantiate a simple classification model
# with batch norm

threeLayerNonLinearModel_batchnorm = tf.keras.Sequential([
  layers.Dense(3),
  EinsumLayer(output_dim=256),
  layers.Dense(256, activation=tf.nn.relu),
  layers.BatchNormalization(),
  layers.Dense(256, activation=tf.nn.relu),
  layers.Dense(1),
])

# %% [markdown]
# ## L1

# %%
# Instantiate a simple classification model
# with l1

threeLayerNonLinearModel_l1 = tf.keras.Sequential([
  layers.Dense(3),
  EinsumLayer(output_dim=256),
  layers.Dense(256, activation=tf.nn.relu, activity_regularizer=l1(0.01)),
  layers.Dense(256, activation='sigmoid'),
  layers.Dense(1),
])

# %% [markdown]
# ## Dropout

# %%
# Instantiate a simple classification model
# with dropout

threeLayerNonLinearModel_dropout = tf.keras.Sequential([
  layers.Dense(3),
  EinsumLayer(output_dim=256),
  layers.Dense(256, activation=tf.nn.relu),
  layers.Dropout(0.10),
  layers.Dense(256, activation=tf.nn.relu),
  layers.Dense(1),
])

# %% [markdown]
# ## Training the Model on the Augmented Training Data for Batch Norm, L1, and Dropout with Earlystop: Validation Loss

# %% [markdown]
# The augmented data generated with TSAug seems to perform better than with the samples synthetically generated from eye-balled distribution estimators in within the previous [Tensorflow](https://github.com/Bryan-Az/TF-PyTorch-Jax-NN) notebook.

# %%
def train_with_early_stopping(model, tf_train_dataset, tf_test_dataset, num_epochs=10):
  accuracy = tf.keras.metrics.MeanSquaredError()
  optimizer = tf.keras.optimizers.SGD()
  best_val_metric = float('inf')
  best_epoch = 0
  patience = 3

  for epoch in range(num_epochs):
    for step, (x, y) in enumerate(tf_train_dataset):
      # Open a GradientTape.
      with tf.GradientTape() as tape:
        # Forward pass.
        logits = model(x)
        # Loss value for this batch.
        loss_value = tf.reduce_mean(tf.keras.losses.mse(y, logits))

      # Get gradients of loss wrt the weights.
      gradients = tape.gradient(loss_value, model.trainable_weights)

      # Update the weights of our linear layer.
      optimizer.apply_gradients(zip(gradients, model.trainable_weights))

      # Update the running accuracy/ MSE in this case
      accuracy.update_state(y, logits)
      # Logging.
      if step % 20 == 0:
        print('Step:', step)
        print('Loss from last step: %.3f' % loss_value)
        print('Total running accuracy so far: %.3f' % accuracy.result())
    # Evaluate the model on the validation set (tf_test_dataset is a numpy array dataset)
    test_predictions = model(tf_test_dataset)
    # set the val_metric to calculate accuracy using predictions and x_test

    def compute_validation_loss(labels, predictions):
      return tf.reduce_mean(tf.keras.losses.mse(labels, predictions))

    val_metric = compute_validation_loss(y_test, test_predictions)

    # Check if the validation metric has improved.
    if val_metric < best_val_metric:
      best_val_metric = val_metric
      best_epoch = epoch
    else:
      # If the validation metric has not improved for 'patience' epochs, stop training.
      if epoch - best_epoch >= patience:
        print('Early stopping at epoch %d.' % epoch)
        print('Valid. Loss at epoch %d.' % best_val_metric)
        break

    print('Epoch %d: last batch loss = %.4f' % (epoch, float(loss_value)))

  return best_epoch

# %%
train_with_early_stopping(threeLayerNonLinearModel_batchnorm, tf_train_dataset, X_test)
# Out:
# Step: 0
# Loss from last step: 0.024
# Total running accuracy so far: 0.024
# Step: 20
# Loss from last step: 0.025
# Total running accuracy so far: 2.562
# Step: 40
# Loss from last step: 5.080
# Total running accuracy so far: 2.015
# Step: 60
# Loss from last step: 0.017
# Total running accuracy so far: 1.923
# Step: 80
# Loss from last step: 0.045
# Total running accuracy so far: 1.614
# Step: 100
# Loss from last step: 0.025
# Total running accuracy so far: 1.348
# Step: 120
# Loss from last step: 27.245
# Total running accuracy so far: 1.362
# Step: 140
# Loss from last step: 0.012
# Total running accuracy so far: 1.254
# Step: 160
# Loss from last step: 0.013
# Total running accuracy so far: 1.141
# Step: 180
# Loss from last step: 0.046
# Total running accuracy so far: 1.164
# Epoch 0: last batch loss = 0.0291
# Step: 0
# Loss from last step: 0.031
# Total running accuracy so far: 1.096
# Step: 20
# Loss from last step: 0.022
# Total running accuracy so far: 1.198
# Step: 40
# Loss from last step: 0.023
# Total running accuracy so far: 1.105
# Step: 60
# Loss from last step: 1.080
# Total running accuracy so far: 1.127
# Step: 80
# Loss from last step: 0.024
# Total running accuracy so far: 1.054
# Step: 100
# Loss from last step: 0.941
# Total running accuracy so far: 1.118
# Step: 120
# Loss from last step: 0.038
# Total running accuracy so far: 1.079
# Step: 140
# Loss from last step: 0.029
# Total running accuracy so far: 1.110
# Step: 160
# Loss from last step: 0.028
# Total running accuracy so far: 1.104
# Step: 180
# Loss from last step: 0.014
# Total running accuracy so far: 1.131
# Epoch 1: last batch loss = 0.0377
# Step: 0
# Loss from last step: 0.034
# Total running accuracy so far: 1.096
# Step: 20
# Loss from last step: 0.022
# Total running accuracy so far: 1.075
# Step: 40
# Loss from last step: 1.136
# Total running accuracy so far: 1.092
# Step: 60
# Loss from last step: 0.023
# Total running accuracy so far: 1.079
# Step: 80
# Loss from last step: 0.027
# Total running accuracy so far: 1.074
# Step: 100
# Loss from last step: 0.018
# Total running accuracy so far: 1.042
# Step: 120
# Loss from last step: 22.711
# Total running accuracy so far: 1.065
# Step: 140
# Loss from last step: 0.103
# Total running accuracy so far: 1.116
# Step: 160
# Loss from last step: 1.243
# Total running accuracy so far: 1.101
# Step: 180
# Loss from last step: 0.039
# Total running accuracy so far: 1.064
# Epoch 2: last batch loss = 0.8749
# Step: 0
# Loss from last step: 0.013
# Total running accuracy so far: 1.095
# Step: 20
# Loss from last step: 0.022
# Total running accuracy so far: 1.094
# Step: 40
# Loss from last step: 0.018
# Total running accuracy so far: 1.107
# Step: 60
# Loss from last step: 1.021
# Total running accuracy so far: 1.139
# Step: 80
# Loss from last step: 0.068
# Total running accuracy so far: 1.159
# Step: 100
# Loss from last step: 0.017
# Total running accuracy so far: 1.139
# Step: 120
# Loss from last step: 0.011
# Total running accuracy so far: 1.139
# Step: 140
# Loss from last step: 0.026
# Total running accuracy so far: 1.112
# Step: 160
# Loss from last step: 3.699
# Total running accuracy so far: 1.105
# Step: 180
# Loss from last step: 23.284
# Total running accuracy so far: 1.112
# Early stopping at epoch 3.
# Valid. Loss at epoch 0.
# 0

# %%
train_with_early_stopping(threeLayerNonLinearModel_l1, tf_train_dataset, X_test)
# Out:
# Step: 0
# Loss from last step: 0.429
# Total running accuracy so far: 0.429
# Step: 20
# Loss from last step: 1.915
# Total running accuracy so far: 1.083
# Step: 40
# Loss from last step: 0.020
# Total running accuracy so far: 2.475
# Step: 60
# Loss from last step: 0.030
# Total running accuracy so far: 1.872
# Step: 80
# Loss from last step: 0.013
# Total running accuracy so far: 1.426
# Step: 100
# Loss from last step: 0.799
# Total running accuracy so far: 1.558
# Step: 120
# Loss from last step: 0.099
# Total running accuracy so far: 1.594
# Step: 140
# Loss from last step: 8.867
# Total running accuracy so far: 1.443
# Step: 160
# Loss from last step: 22.354
# Total running accuracy so far: 1.443
# Step: 180
# Loss from last step: 0.087
# Total running accuracy so far: 1.450
# Epoch 0: last batch loss = 0.0186
# Step: 0
# Loss from last step: 0.023
# Total running accuracy so far: 1.344
# Step: 20
# Loss from last step: 0.020
# Total running accuracy so far: 1.409
# Step: 40
# Loss from last step: 0.013
# Total running accuracy so far: 1.350
# Step: 60
# Loss from last step: 8.666
# Total running accuracy so far: 1.344
# Step: 80
# Loss from last step: 0.016
# Total running accuracy so far: 1.282
# Step: 100
# Loss from last step: 0.198
# Total running accuracy so far: 1.256
# Step: 120
# Loss from last step: 1.416
# Total running accuracy so far: 1.298
# Step: 140
# Loss from last step: 0.064
# Total running accuracy so far: 1.395
# Step: 160
# Loss from last step: 0.956
# Total running accuracy so far: 1.442
# Step: 180
# Loss from last step: 0.007
# Total running accuracy so far: 1.395
# Epoch 1: last batch loss = 0.0244
# Step: 0
# Loss from last step: 0.011
# Total running accuracy so far: 1.341
# Step: 20
# Loss from last step: 0.144
# Total running accuracy so far: 1.340
# Step: 40
# Loss from last step: 0.026
# Total running accuracy so far: 1.310
# Step: 60
# Loss from last step: 0.019
# Total running accuracy so far: 1.263
# Step: 80
# Loss from last step: 22.826
# Total running accuracy so far: 1.270
# Step: 100
# Loss from last step: 0.221
# Total running accuracy so far: 1.253
# Step: 120
# Loss from last step: 0.958
# Total running accuracy so far: 1.283
# Step: 140
# Loss from last step: 1.710
# Total running accuracy so far: 1.255
# Step: 160
# Loss from last step: 0.025
# Total running accuracy so far: 1.322
# Step: 180
# Loss from last step: 0.017
# Total running accuracy so far: 1.364
# Epoch 2: last batch loss = 0.0128
# Step: 0
# Loss from last step: 0.016
# Total running accuracy so far: 1.368
# Step: 20
# Loss from last step: 0.009
# Total running accuracy so far: 1.400
# Step: 40
# Loss from last step: 4.443
# Total running accuracy so far: 1.442
# Step: 60
# Loss from last step: 0.018
# Total running accuracy so far: 1.426
# Step: 80
# Loss from last step: 0.005
# Total running accuracy so far: 1.440
# Step: 100
# Loss from last step: 0.016
# Total running accuracy so far: 1.430
# Step: 120
# Loss from last step: 0.022
# Total running accuracy so far: 1.398
# Step: 140
# Loss from last step: 1.719
# Total running accuracy so far: 1.379
# Step: 160
# Loss from last step: 0.032
# Total running accuracy so far: 1.402
# Step: 180
# Loss from last step: 0.023
# Total running accuracy so far: 1.374
# Epoch 3: last batch loss = 8.2165
# Step: 0
# Loss from last step: 1.506
# Total running accuracy so far: 1.354
# Step: 20
# Loss from last step: 0.019
# Total running accuracy so far: 1.325
# Step: 40
# Loss from last step: 0.016
# Total running accuracy so far: 1.368
# Step: 60
# Loss from last step: 0.207
# Total running accuracy so far: 1.404
# Step: 80
# Loss from last step: 0.119
# Total running accuracy so far: 1.412
# Step: 100
# Loss from last step: 0.003
# Total running accuracy so far: 1.395
# Step: 120
# Loss from last step: 0.019
# Total running accuracy so far: 1.372
# Step: 140
# Loss from last step: 0.024
# Total running accuracy so far: 1.362
# Step: 160
# Loss from last step: 0.234
# Total running accuracy so far: 1.342
# Step: 180
# Loss from last step: 0.025
# Total running accuracy so far: 1.389
# Epoch 4: last batch loss = 1.1064
# Step: 0
# Loss from last step: 0.208
# Total running accuracy so far: 1.365
# Step: 20
# Loss from last step: 1.073
# Total running accuracy so far: 1.343
# Step: 40
# Loss from last step: 0.038
# Total running accuracy so far: 1.360
# Step: 60
# Loss from last step: 0.155
# Total running accuracy so far: 1.343
# Step: 80
# Loss from last step: 0.018
# Total running accuracy so far: 1.352
# Step: 100
# Loss from last step: 0.019
# Total running accuracy so far: 1.337
# Step: 120
# Loss from last step: 0.013
# Total running accuracy so far: 1.342
# Step: 140
# Loss from last step: 4.512
# Total running accuracy so far: 1.361
# Step: 160
# Loss from last step: 0.053
# Total running accuracy so far: 1.369
# Step: 180
# Loss from last step: 1.629
# Total running accuracy so far: 1.372
# Early stopping at epoch 5.
# Valid. Loss at epoch 0.
# 2

# %%
train_with_early_stopping(threeLayerNonLinearModel_dropout, tf_train_dataset, X_test)
# Out:
# Step: 0
# Loss from last step: 1.076
# Total running accuracy so far: 1.076
# Step: 20
# Loss from last step: 0.013
# Total running accuracy so far: 0.122
# Step: 40
# Loss from last step: 0.027
# Total running accuracy so far: 1.109
# Step: 60
# Loss from last step: 0.022
# Total running accuracy so far: 0.781
# Step: 80
# Loss from last step: 0.029
# Total running accuracy so far: 1.039
# Step: 100
# Loss from last step: 0.022
# Total running accuracy so far: 1.029
# Step: 120
# Loss from last step: 23.332
# Total running accuracy so far: 1.113
# Step: 140
# Loss from last step: 0.017
# Total running accuracy so far: 1.092
# Step: 160
# Loss from last step: 0.046
# Total running accuracy so far: 1.230
# Step: 180
# Loss from last step: 0.025
# Total running accuracy so far: 1.157
# Epoch 0: last batch loss = 0.0089
# Step: 0
# Loss from last step: 0.030
# Total running accuracy so far: 1.094
# Step: 20
# Loss from last step: 0.035
# Total running accuracy so far: 1.063
# Step: 40
# Loss from last step: 0.034
# Total running accuracy so far: 1.019
# Step: 60
# Loss from last step: 0.023
# Total running accuracy so far: 0.968
# Step: 80
# Loss from last step: 1.107
# Total running accuracy so far: 0.970
# Step: 100
# Loss from last step: 8.583
# Total running accuracy so far: 0.965
# Step: 120
# Loss from last step: 1.007
# Total running accuracy so far: 1.053
# Step: 140
# Loss from last step: 0.022
# Total running accuracy so far: 1.158
# Step: 160
# Loss from last step: 1.697
# Total running accuracy so far: 1.137
# Step: 180
# Loss from last step: 0.050
# Total running accuracy so far: 1.147
# Epoch 1: last batch loss = 0.9140
# Step: 0
# Loss from last step: 0.030
# Total running accuracy so far: 1.096
# Step: 20
# Loss from last step: 0.022
# Total running accuracy so far: 1.072
# Step: 40
# Loss from last step: 0.017
# Total running accuracy so far: 1.033
# Step: 60
# Loss from last step: 0.020
# Total running accuracy so far: 0.996
# Step: 80
# Loss from last step: 7.519
# Total running accuracy so far: 1.064
# Step: 100
# Loss from last step: 0.023
# Total running accuracy so far: 1.074
# Step: 120
# Loss from last step: 22.914
# Total running accuracy so far: 1.102
# Step: 140
# Loss from last step: 0.014
# Total running accuracy so far: 1.080
# Step: 160
# Loss from last step: 0.044
# Total running accuracy so far: 1.089
# Step: 180
# Loss from last step: 0.023
# Total running accuracy so far: 1.052
# Epoch 2: last batch loss = 0.0518
# Step: 0
# Loss from last step: 0.031
# Total running accuracy so far: 1.096
# Step: 20
# Loss from last step: 0.014
# Total running accuracy so far: 1.133
# Step: 40
# Loss from last step: 0.011
# Total running accuracy so far: 1.108
# Step: 60
# Loss from last step: 8.574
# Total running accuracy so far: 1.094
# Step: 80
# Loss from last step: 3.408
# Total running accuracy so far: 1.125
# Step: 100
# Loss from last step: 0.034
# Total running accuracy so far: 1.106
# Step: 120
# Loss from last step: 0.013
# Total running accuracy so far: 1.099
# Step: 140
# Loss from last step: 0.027
# Total running accuracy so far: 1.105
# Step: 160
# Loss from last step: 0.039
# Total running accuracy so far: 1.096
# Step: 180
# Loss from last step: 0.008
# Total running accuracy so far: 1.075
# Epoch 3: last batch loss = 0.0209
# Step: 0
# Loss from last step: 0.036
# Total running accuracy so far: 1.095
# Step: 20
# Loss from last step: 0.030
# Total running accuracy so far: 1.070
# Step: 40
# Loss from last step: 0.023
# Total running accuracy so far: 1.084
# Step: 60
# Loss from last step: 0.046
# Total running accuracy so far: 1.110
# Step: 80
# Loss from last step: 0.015
# Total running accuracy so far: 1.090
# Step: 100
# Loss from last step: 1.838
# Total running accuracy so far: 1.081
# Step: 120
# Loss from last step: 0.029
# Total running accuracy so far: 1.075
# Step: 140
# Loss from last step: 0.009
# Total running accuracy so far: 1.077
# Step: 160
# Loss from last step: 0.009
# Total running accuracy so far: 1.063
# Step: 180
# Loss from last step: 0.778
# Total running accuracy so far: 1.090
# Early stopping at epoch 4.
# Valid. Loss at epoch 0.
# 1

# %% [markdown]
# # Evaluating the sample 'Dropout' Model on the Augmented Testing Data

# %% [markdown]
# ## The Real Data Y 'Truth' Labels

# %%
X = filtered_numerical_features.loc[:, ['biodiversity_0', 'biodiversity_1','working_capacity_3']].copy(deep=True)
y = filtered_numerical_features.loc[:, ['target']].copy(deep=True)

# %%
plot_4d(X['biodiversity_0'], X['biodiversity_1'], X['working_capacity_3'], y, title='Biodiversity (0 & 1) & working capacity (3) colored by Target')

# %% [markdown]
# ## The Real Data Y 'Prediction' Labels

# %%
X
# Out:
#       biodiversity_0  biodiversity_1  working_capacity_3
# 8391           422.0       418.64977          445.799955
# 7419             5.0       349.00000          105.000000
# 7420             5.0       693.00000          199.000000
# 7421             5.0       299.00000           44.000000
# 7422             4.0       785.00000          776.000000
# ...              ...             ...                 ...
# 1195            11.0       138.00000          380.000000
# 1196             5.0       764.00000          258.000000
# 1197             2.0        22.00000          552.000000
# 1189            65.0       880.00000           66.000000
# 0              310.0       418.64977          445.799955
#
# [6557 rows x 3 columns]

# %%
predictions = threeLayerNonLinearModel_dropout(X.to_numpy())

# %%
plot_4d(X['biodiversity_0'], X['biodiversity_1'], X['working_capacity_3'], predictions, title='Biodiversity (0 & 1) & working capacity (3) features colored by Target')

# %% [markdown]
# ## The Simulated Data Y 'Truth' Labels

# %%
plot_4d(X_test[:,0], X_test[:,1], X_test[:,2], y_test, title='Biodiversity (0 & 1) & working capacity (3) features colored by Target')

# %% [markdown]
# ## The Simulated Data Y 'Prediction' Labels

# %%
simulated_test_predictions = threeLayerNonLinearModel_batchnorm(X_test)

# %%
plot_4d(X_test[:,0], X_test[:,1], X_test[:,2], simulated_test_predictions[:,0], title='Biodiversity (0 & 1) & working capacity (3) features in 2018 colored by Target')

# %% [markdown]
# <a href="https://colab.research.google.com/github/Bryan-Az/TF-PyTorch-Jax-NN/blob/main/Tensorflow-NN/EinsumVMatrix.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
